# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="41861c94e8ee4c2a9aec81d3ea327013",
                                                           client_secret="13fd6a7d69424cc688a1be0fa25e3dff"))

# %%
playlist = sp.user_playlist_tracks("spotify", "2lCQHWwiVVtY0kCCTFdGtF")

# %%
tracks = playlist["total"]

# %%
tracks
# Out:
# 78

# %% [markdown]
# ## get artist name

# %%
playlist["items"][10]['track']['album']['artists'][0]['name']
# Out:
# 'Limp Bizkit'

# %%
artist_names = []
for i in range (playlist["total"]):
    artist_names.append(playlist["items"][i]['track']['album']['artists'][0]['name'])

# %%
unique_artists = []

# Iterate through the original list
for item in artist_names:
    if item not in unique_artists:
        unique_artists.append(item)

# %%
df = pd.DataFrame({'Artist Name': artist_names})

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                          Artist Name
# 0                             Eminem
# 2                    Various Artists
# 3                           DJ Fresh
# 4                        Yellow Claw
# 5                          Desiigner
# 6                            Nirvana
# 8                      Flux Pavilion
# 9                        Limp Bizkit
# 11                  Hollywood Undead
# 12                            M.O.P.
# 13                           DJ Kool
# 14                    Chase & Status
# 16                        Cut Killer
# 17                               DMX
# 19                        Papa Roach
# 20  Rob Bailey & The Hustle Standard
# 21                               D12
# 22                            P.O.D.
# 23                        AWOLNATION
# 24                           Moderat
# 25                 Machine Gun Kelly
# 26                             Logic
# 27                        BlocBoy JB
# 28                        Guano Apes
# ...

# %% [markdown]
# ## Get the features of the songs

# %%
results = sp.search(q='artist:eminem', limit=5, type='track')

# %%
results['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/search?query=artist%3Aeminem&type=track&offset=0&limit=5',
#  'items': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
# ...

# %%
results['tracks']['items'][1]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#     'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#     'id': '7dGJo4pcD2V6oG8kP0tJRR',
#     'name': 'Eminem',
#     'type': 'artist',
#     'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
results['track']

# %%
def get_playlist_tracks(username, playlist_id):

    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']

    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])

    return tracks

tracks = get_playlist_tracks("spotify", "2lCQHWwiVVtY0kCCTFdGtF")
tracks
# Out:
# [{'added_at': '2017-03-23T15:28:40Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maxwilms050'},
#    'href': 'https://api.spotify.com/v1/users/maxwilms050',
#    'id': 'maxwilms050',
#    'type': 'user',
#    'uri': 'spotify:user:maxwilms050'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1ftvBBcu7jYIvXyt3JWB8S'},
#     'href': 'https://api.spotify.com/v1/albums/1ftvBBcu7jYIvXyt3JWB8S',
#     'id': '1ftvBBcu7jYIvXyt3JWB8S',
#     'images': [{'height': 640,
# ...

# %%
def get_artists_ids_from_playlist(playlist_id):

    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)

    artists_ids = []

    for track in tracks_from_playlist:
        artists_info = track['track']['artists']

        for artist_info in artists_info:
            artists_ids.append(artist_info['id'])

    return list(set(artists_ids))

artists_ids = get_artists_ids_from_playlist("2lCQHWwiVVtY0kCCTFdGtF")
artists_ids
# Out:
# ['5IcR3N7QB1j6KBL8eImZ8m',
#  '1dMdLlZI5X74N3yhF5qgEJ',
#  '6DPYiyq5kWVQS4RGwxzPC7',
#  '7hJcb9fa4alzcOq3EaNPoG',
#  '73sIBHcqh3Z3NyqHKZ7FOL',
#  '4S15WJMMR2rCQv34qBmjzy',
#  '17lzZA2AlOHwCwFALHttmp',
#  '2hPgGN4uhvXAxiXQBIXOmE',
#  '0CEFCo8288kQU7mJi25s6E',
#  '6r20qOqY7qDWI0PPTxVMlC',
#  '3TVXtAsR1Inumwj472S9r4',
#  '0ONHkAv9pCAFxb0zJwDNTy',
#  '37Qsf5KCKljH7mL134xp4k',
#  '1Rge556vxecXsIcTxzxOBa',
#  '6FyRbuLLpPFzeI63apcfLi',
#  '6l3HvQ5sa6mXTsMTB19rO5',
#  '47z7ZrgFoBvVpCnElCE3Zh',
#  '6olE6TJLqED3rqDCT0FyPh',
#  '7362Tj1IkoHp7oWveGTf51',
#  '0Y5tJX1MQlPlqiwlOH1tJY',
#  '5XenQ7XfcvQdfIbpLEFaKQ',
#  '0c173mlxpT3dSFRgMO8XPh',
#  '55Aa2cqylxrFIXC767Z865',
#  '7muzHifhMdnfN1xncRLOqk',
#  '4MCBfE4596Uoi2O4DtmEMz',
#  '4xRYI6VqpkE3UwrDrAZL8L',
#  '5K4W6rqBFWDnAN6FQUkS6x',
#  '7BAaznGSsqcksud4R5ou5z',
#  '6WSTevYt4rGwm8QPKQr7dU',
#  '51Pn4gGnZuyOMDfIT1Zy3N',
#  '6wFId9Jhuf9AKVzWboOj2B',
#  '7MseR8aIHbFMXzMAkRPCZy',
#  '1z7b1Pr1rSlvWRzsW3HOrS',
#  '3r1XkJ7vCs8kHBSzGvPLdP',
# ...

# %%
track_ids = [track['track']['uri'] for track in tracks]
track_ids
# Out:
# ['spotify:track:6yr8GiTHWvFfi4o6Q5ebdT',
#  'spotify:track:00WB8iObyyothyu4W3BTqa',
#  'spotify:track:66ZZ9lN9KKiA8zplDXM7GX',
#  'spotify:track:3wpBsYdDQxvqv6yw9uJqGK',
#  'spotify:track:1ivuWgxFQb2xzxVNSlB1hF',
#  'spotify:track:5YEOzOojehCqxGQCcQiyR4',
#  'spotify:track:1f3yAtsJtY87CTmM8RLnxf',
#  'spotify:track:3zmduBNsQ6BPDTZAkXzG5K',
#  'spotify:track:03EuhmMsEHVFI9ytainStU',
#  'spotify:track:1jH2IzZ7JnixFoGG6XSnpf',
#  'spotify:track:2xI7o9zYcqynmueNH4foku',
#  'spotify:track:3XdAzyVBwPctMDkFjKRlO7',
#  'spotify:track:5osSw3tL07Tuid7AWsvYcc',
#  'spotify:track:6zxduHMczryEbhZ5NGyiPU',
#  'spotify:track:1KNWLV6YchpDzqxkrb7AnC',
#  'spotify:track:52LrKVv3IZEybNHDg6SLAe',
#  'spotify:track:4udc6XovxThag5LUUZfbiX',
#  'spotify:track:2NeHnSFnwNp1Z5WYgcjJ8L',
#  'spotify:track:32SFvZODywPBVDYSYtqxCj',
#  'spotify:track:0SjhCnjTT2bXD9RtU8bFT9',
#  'spotify:track:6fd3mZrsVbe7N6whWrlZYv',
#  'spotify:track:5OY8EtE7tt2nM4c0oxhJY8',
#  'spotify:track:5DooySfCD1xCJ49gQm9rx7',
# ...

# %%
pd.json_normalize(sp.audio_features(track_ids))
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.551   0.851    1    -3.277     1       0.1970      0.074800
# 1          0.687   0.744    1    -6.698     0       0.4580      0.080400
# 2          0.622   0.826    2    -6.682     1       0.2340      0.040400
# 3          0.310   0.926    6    -1.131     0       0.0464      0.018400
# 4          0.829   0.695    1    -5.561     1       0.0473      0.000956
# ..           ...     ...  ...       ...   ...          ...           ...
# 73         0.672   0.704    1   -10.066     0       0.3120      0.173000
# 74         0.673   0.892   10    -7.175     0       0.2420      0.190000
# 75         0.563   0.496    6    -9.381     0       0.4060      0.068500
# 76         0.767   0.677   11    -6.128     0       0.1840      0.033900
# 77         0.813   0.621    9    -9.273     1       0.2090      0.014400
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...
